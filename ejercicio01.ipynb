# %% [markdown]
# ## Definir las siguientes funciones usando lambdas.

# %% [markdown]
# ### a. Crear una lambda que reciba un número y devuelva True si es múltiplo de 3, False en caso contrario.

# %%
mul_3 = lambda x: True if (x % 3) == 0 else False
print(mul_3(30))
# Out:
# True

# %% [markdown]
# ### b. Crear una lambda que reciba un número y devuelva su cubo.

# %%
cubo_num = lambda x: (x ** 3)
print(cubo_num(3))
# Out:
# 27

# %% [markdown]
# #### c. Crear una lambda que reciba dos números y devuelva su producto.

# %%
prod_num = lambda x, y: (x * y)
print(prod_num(3,5))
# Out:
# 15

# %% [markdown]
# ### d. Crear una lambda que reciba dos números y devuelva el mayor.

# %%
mayor_x_y = lambda x,y: x if x > y else y
print(mayor_x_y(30,10))
# Out:
# 30

# %% [markdown]
# ### e. Crear una lambda que reciba una palabra y devuelva True si empieza con la letra “A" (o “a”).

# %%
starts_with_aA = lambda p: True if p.startswith("a") or p.startswith("A")  else False
print(starts_with_aA("Aveces"))
# Out:
# True

# %% [markdown]
# ### f. Crear una lambda que reciba una temperatura en Celsius y la convierta a Fahrenheit.

# %%
convert_celsius = lambda t: t*1.8 + 32
print(convert_celsius(45))
# Out:
# 113.0

# %% [markdown]
# ## Realizar el siguiente ejercicio usando lambdas

# %% [markdown]
# ### Crear una lista que contenga tres lambdas:
#
# - Una que duplique un número
# - Una que le sume 10
# - Una que calcule su cuadrado

# %%
lista_3_lambdas = [lambda x: x*2, lambda x: x+10, lambda x:x**2]
print(lista_3_lambdas)

numero = int(input("num?: "))
for fn in lista_3_lambdas:
    print(fn(numero))
# Out:
# [<function <lambda> at 0x000002A31C39FA60>, <function <lambda> at 0x000002A31BDC5D00>, <function <lambda> at 0x000002A31C584540>]
# 8
# 14
# 16
